# %% [markdown]
# <a href="https://colab.research.google.com/github/shreya-t-nagappanavar/Project_2_Black_Friday_Sales_Data_Analysis/blob/main/3_Black_Friday_Sales_Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('/content/sample_data/BlackFriday.csv')

# %%
df.head(2)
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200

# %%
del df['Product_Category_2']
del df['Product_Category_3']

# %%
df.head(2)
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase
# 0                          2               0                   3      8370
# 1                          2               0                   1     15200

# %% [markdown]
# # Analysis with Stay_In_Current_City_Years

# %%
sns.countplot(x = df['Stay_In_Current_City_Years'])
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sns.countplot(x = 'Stay_In_Current_City_Years' , hue = 'Gender', data = df)
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
df.groupby('Stay_In_Current_City_Years').sum()['Purchase'].plot(kind = 'bar', title = 'People purchased based on year wise')
# Out:
# <ipython-input-10-940075479dcc>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Stay_In_Current_City_Years').sum()['Purchase'].plot(kind = 'bar', title = 'People purchased based on year wise')
# <Axes: title={'center': 'People purchased based on year wise'}, xlabel='Stay_In_Current_City_Years'>

# %%
df.groupby('Occupation').sum()['Purchase'].plot(kind = 'bar', title = 'People purchased based on year wise')
# Out:
# <ipython-input-11-125ce7753011>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Occupation').sum()['Purchase'].plot(kind = 'bar', title = 'People purchased based on year wise')
# <Axes: title={'center': 'People purchased based on year wise'}, xlabel='Occupation'>

# %%
sns.countplot(x = 'Stay_In_Current_City_Years' , hue = 'Marital_Status', data = df)
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
df.columns
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Purchase'],
#       dtype='object')

# %%
sns.countplot(x = 'Stay_In_Current_City_Years' , hue = 'City_Category', data = df)
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sns.countplot(data = df, x = 'City_Category')
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
sns.countplot(data = df, x = 'City_Category', hue = 'Age')
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
sns.countplot(data = df, x = 'City_Category', hue = 'Marital_Status')
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
df.groupby('City_Category').sum()['Purchase'].plot(kind = 'pie', title = 'Based on category', figsize = (4,4), autopct = '%0.1f')
# Out:
# <ipython-input-23-1f0782fb932b>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('City_Category').sum()['Purchase'].plot(kind = 'pie', title = 'Based on category', figsize = (4,4), autopct = '%0.1f')
# <Axes: title={'center': 'Based on category'}, ylabel='Purchase'>

# %%
df.groupby('Age').sum()['Purchase'].plot(kind = 'pie', title = 'Based on category', figsize = (4,4), autopct = '%0.1f')
# Out:
# <ipython-input-24-c18a06c792a8>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Age').sum()['Purchase'].plot(kind = 'pie', title = 'Based on category', figsize = (4,4), autopct = '%0.1f')
# <Axes: title={'center': 'Based on category'}, ylabel='Purchase'>

# %%
sns.countplot(x = df['Occupation'], color = 'black')
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
df.groupby('Occupation').size().sort_values().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Occupation'>

# %%
df.groupby('Stay_In_Current_City_Years').size().sort_values().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years'>

# %%
df.groupby('Stay_In_Current_City_Years').mean()['Purchase'].sort_values().plot(kind = 'bar', color = 'pink')
# Out:
# <ipython-input-32-214e44d383f3>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Stay_In_Current_City_Years').mean()['Purchase'].sort_values().plot(kind = 'bar', color = 'pink')
# <Axes: xlabel='Stay_In_Current_City_Years'>

# %%
sns.countplot(x = 'Occupation', hue = 'Marital_Status', data = df)
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
sns.countplot(x = 'Occupation', hue = 'Gender', data = df)
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
df.groupby('Occupation').nunique()['Product_ID']
# Out:
# Occupation
# 0     3243
# 1     3020
# 2     2892
# 3     2657
# 4     3174
# 5     2344
# 6     2724
# 7     3070
# 8     1026
# 9     1820
# 10    2110
# 11    2235
# 12    2664
# 13    1946
# 14    2680
# 15    2168
# 16    2863
# 17    2831
# 18    2047
# 19    2303
# 20    3147
# Name: Product_ID, dtype: int64

# %%
df.groupby('Occupation').nunique()['Product_ID'].plot(kind = 'pie', figsize = (4,4), autopct = '%0.1f')
# Out:
# <Axes: ylabel='Product_ID'>

# %%
df.groupby('Occupation').nunique()['Product_ID'].plot(kind = 'bar', figsize = (4,4), color = 'green')
# Out:
# <Axes: xlabel='Occupation'>

# %%
df.groupby('Occupation').nunique()['Product_ID'].plot(kind = 'bar', figsize = (4,4), color = 'green')
# Out:
# <Axes: xlabel='Occupation'>

# %%
df.groupby('Occupation').nunique()['Product_ID'].sort_values().plot(kind = 'bar', figsize = (4,4), color = 'green')
# Out:
# <Axes: xlabel='Occupation'>

# %%
df.groupby('Occupation').nunique()['Product_ID'].nlargest(10).plot(kind = 'bar', figsize = (4,4), color = 'purple')
# Out:
# <Axes: xlabel='Occupation'>

# %%
df.groupby('Occupation').sum()['Purchase'].nlargest(5).plot(kind = 'bar', figsize = (4,4), color = 'red')
# Out:
# <ipython-input-44-e1693c6a0802>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Occupation').sum()['Purchase'].nlargest(5).plot(kind = 'bar', figsize = (4,4), color = 'red')
# <Axes: xlabel='Occupation'>

# %% [markdown]
# # Analysis of Gender and with marital status

# %%
df.head(2)
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase
# 0                          2               0                   3      8370
# 1                          2               0                   1     15200

# %%
l = []
for i in range(len(df)):
  l.append(df['Gender'][i] + "_" + str(df['Marital_Status'][i]))

# %%
l
# Out:
# ['F_0',
#  'F_0',
#  'F_0',
#  'F_0',
#  'M_0',
#  'M_0',
#  'M_1',
#  'M_1',
#  'M_1',
#  'M_1',
#  'M_1',
#  'M_1',
#  'M_1',
#  'M_1',
#  'F_0',
#  'F_0',
#  'F_0',
#  'F_0',
#  'M_1',
#  'M_1',
#  'M_1',
#  'M_1',
#  'M_1',
#  'M_1',
#  'M_1',
#  'M_0',
#  'M_0',
#  'M_0',
#  'M_0',
#  'F_1',
#  'F_1',
#  'F_1',
#  'F_1',
#  'F_1',
#  'F_1',
#  'F_1',
#  'F_1',
#  'F_1',
#  'F_1',
#  'F_1',
#  'F_1',
#  'F_1',
#  'F_1',
#  'F_1',
#  'F_1',
#  'F_1',
#  'F_1',
#  'F_0',
#  'F_0',
#  'F_0',
#  'M_0',
#  'M_0',
#  'M_1',
#  'M_1',
#  'M_1',
#  'M_0',
#  'M_0',
#  'M_0',
#  'M_0',
#  'M_0',
#  'M_0',
#  'M_0',
#  'M_0',
#  'M_0',
#  'M_0',
#  'F_1',
#  'F_1',
#  'M_0',
#  'M_0',
#  'M_0',
#  'F_0',
#  'F_0',
#  'F_0',
#  'F_0',
#  'F_0',
#  'F_0',
#  'F_0',
#  'F_0',
#  'F_0',
#  'F_0',
#  'F_0',
#  'F_0',
#  'F_0',
#  'F_0',
#  'F_0',
#  'M_0',
#  'M_0',
#  'M_0',
#  'M_0',
#  'M_0',
#  'M_0',
#  'M_0',
#  'M_0',
#  'M_0',
#  'M_0',
#  'M_0',
#  'M_0',
#  'M_0',
#  'M_0',
#  'M_0',
# ...

# %%
df['Marital_Gender'] = l

# %%
df.head(2)
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase  \
# 0                          2               0                   3      8370
# 1                          2               0                   1     15200
#
#   Marital_Gender
# 0            F_0
# 1            F_0

# %%
sns.countplot(x = df['Marital_Gender'])
# Out:
# <Axes: xlabel='Marital_Gender', ylabel='count'>

# %%
sns.countplot(x = 'Age',hue = 'Marital_Gender', data = df)
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
sns.countplot(x = 'Product_Category_1',hue = 'Marital_Gender', data = df)
# Out:
# <Axes: xlabel='Product_Category_1', ylabel='count'>

# %%
sns.countplot(x = 'Stay_In_Current_City_Years',hue = 'Marital_Gender', data = df)
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sns.countplot(x = 'City_Category',hue = 'Marital_Gender', data = df)
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>
