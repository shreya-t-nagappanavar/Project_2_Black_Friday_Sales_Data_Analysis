# %% [markdown]
# <a href="https://colab.research.google.com/github/shreya-t-nagappanavar/Project_2_Black_Friday_Sales_Data_Analysis/blob/main/2_Black_Friday_Sales_Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Analysis with Age

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv("/content/sample_data/BlackFriday.csv")

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# ...

# %%
del df['Product_Category_2']
del df['Product_Category_3']

# %%
df.head(2)
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase
# 0                          2               0                   3      8370
# 1                          2               0                   1     15200

# %%
df['Age'].unique()
# Out:
# array(['0-17', '55+', '26-35', '46-50', '51-55', '36-45', '18-25'],
#       dtype=object)

# %%
df.groupby('Age').size()
# Out:
# Age
# 0-17      14707
# 18-25     97634
# 26-35    214690
# 36-45    107499
# 46-50     44526
# 51-55     37618
# 55+       20903
# dtype: int64

# %%
df.groupby('Age').size().plot(kind = 'bar', figsize= (4,4), title = 'Purchase Distribution by Age')
# Out:
# <Axes: title={'center': 'Purchase Distribution by Age'}, xlabel='Age'>

# %%
df[df['Age'] == '0-17']
# Out:
#         User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0       1000001  P00069042      F  0-17          10             A
# 1       1000001  P00248942      F  0-17          10             A
# 2       1000001  P00087842      F  0-17          10             A
# 3       1000001  P00085442      F  0-17          10             A
# 85      1000019  P00112542      M  0-17          10             A
# ...         ...        ...    ...   ...         ...           ...
# 537280  1004690  P00242742      F  0-17          10             C
# 537281  1004690  P00226442      F  0-17          10             C
# 537282  1004690  P00181442      F  0-17          10             C
# 537283  1004690  P00192042      F  0-17          10             C
# 537354  1004707  P00253042      M  0-17           0             C
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
for i in df['Age'].unique():
  print(i)
# Out:
# 0-17
# 55+
# 26-35
# 46-50
# 51-55
# 36-45
# 18-25

# %%
len(df[df['Age'] == '0-17'])
# Out:
# 14707

# %%
len(df[df['Age'] == '55+'])
# Out:
# 20903

# %%
df[df['Age'] == i]['Product_ID'].nunique()
# Out:
# 3213

# %%
i
# Out:
# '18-25'

# %%
for i in df['Age'].unique():
  print(i,':',df[df['Age'] == i]['Product_ID'].nunique())
# Out:
# 0-17 : 2300
# 55+ : 2573
# 26-35 : 3419
# 46-50 : 3099
# 51-55 : 2877
# 36-45 : 3318
# 18-25 : 3213

# %%
lst = []
for i in df['Age'].unique():
  lst.append([i,':',df[df['Age'] == i]['Product_ID'].nunique()])
data = pd.DataFrame(lst)

# %%
data.plot(kind = "bar", figsize = (4,4), title = 'Unique Purchase')
# Out:
# <Axes: title={'center': 'Unique Purchase'}>

# %%
df.groupby('Age').sum()['Purchase'].plot(kind = 'bar', figsize= (4,4), title = 'Amount Spent by Age')
# Out:
# <ipython-input-29-791d2b5bf911>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Age').sum()['Purchase'].plot(kind = 'bar', figsize= (4,4), title = 'Amount Spent by Age')
# <Axes: title={'center': 'Amount Spent by Age'}, xlabel='Age'>

# %%
df.groupby('Age').sum().plot(kind = 'bar', figsize= (4,4), title = 'Amount Spent by Age')
# Out:
# <ipython-input-28-18c3edf3f633>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Age').sum().plot(kind = 'bar', figsize= (4,4), title = 'Amount Spent by Age')
# <Axes: title={'center': 'Amount Spent by Age'}, xlabel='Age'>

# %% [markdown]
# # Anaysis with Marital_Status

# %%
df['Marital_Status']
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 537572    0
# 537573    0
# 537574    0
# 537575    0
# 537576    0
# Name: Marital_Status, Length: 537577, dtype: int64

# %%
df.groupby('Marital_Status').size()
# Out:
# Marital_Status
# 0    317817
# 1    219760
# dtype: int64

# %%
df.groupby('Marital_Status').size().plot(kind  = 'pie', title = 'Marital Status', autopct = '%0.1f')
# Out:
# <Axes: title={'center': 'Marital Status'}>

# %%
df.groupby('Marital_Status').sum()['Purchase'].plot(kind  = 'bar', title = 'Marital Status')
# Out:
# <ipython-input-39-ff41a95699f9>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Marital_Status').sum()['Purchase'].plot(kind  = 'bar', title = 'Marital Status')
# <Axes: title={'center': 'Marital Status'}, xlabel='Marital_Status'>

# %%
df.groupby('Age').sum()['Marital_Status']#.plot(kind  = 'bar', title = 'Marital Status')
# Out:
# <ipython-input-41-7dc9cf5780bf>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Age').sum()['Marital_Status']#.plot(kind  = 'bar', title = 'Marital Status')
# Age
# 0-17         0
# 18-25    20641
# 26-35    84166
# 36-45    42507
# 46-50    32194
# 51-55    26979
# 55+      13273
# Name: Marital_Status, dtype: int64

# %%
df.groupby('Age').sum()['Marital_Status'].plot(kind  = 'bar', title = 'Marital Status')
# Out:
# <ipython-input-42-371df9e4655d>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Age').sum()['Marital_Status'].plot(kind  = 'bar', title = 'Marital Status')
# <Axes: title={'center': 'Marital Status'}, xlabel='Age'>

# %%
df.groupby('Age').mean()['Purchase']
# Out:
# <ipython-input-43-7efd67be42ae>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Age').mean()['Purchase']
# Age
# 0-17     9020.126878
# 18-25    9235.197575
# 26-35    9314.588970
# 36-45    9401.478758
# 46-50    9284.872277
# 51-55    9620.616620
# 55+      9453.898579
# Name: Purchase, dtype: float64

# %%
df.groupby('Age').mean()['Purchase'].plot(kind = 'pie', title = 'Mean of purchase by age',autopct = '%0.1f')
# Out:
# <ipython-input-45-785e47a47454>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Age').mean()['Purchase'].plot(kind = 'pie', title = 'Mean of purchase by age',autopct = '%0.1f')
# <Axes: title={'center': 'Mean of purchase by age'}, ylabel='Purchase'>

# %%
df.groupby('Marital_Status').sum()['Purchase'].plot(kind = 'pie', title = 'Mean of purchase by age',autopct = '%0.1f')
# Out:
# <ipython-input-46-89bf93158cb3>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Marital_Status').sum()['Purchase'].plot(kind = 'pie', title = 'Mean of purchase by age',autopct = '%0.1f')
# <Axes: title={'center': 'Mean of purchase by age'}, ylabel='Purchase'>

# %% [markdown]
# # Anaysis with Multi Column

# %%
sns.set(rc = {'figure.figsize' : (12,6)})
sns.countplot(x = 'Age' ,hue = 'Gender' , data = df)
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
sns.set(rc = {'figure.figsize' : (12,6)})
sns.countplot(x = 'Gender' ,hue = 'Age' , data = df)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.displot(x = 'Age',y = 'Gender',data = df)

# %%
sns.set(rc = {'figure.figsize' : (6,6)})
sns.countplot(x = 'Gender' ,hue = 'Marital_Status' , data = df)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.countplot(x = df['City_Category'])
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
sns.countplot(x = df['Age'])
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
df.groupby('City_Category').sum()['Purchase'].plot(kind = 'pie', autopct = '%0.1f')
# Out:
# <ipython-input-60-180920c89d1e>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('City_Category').sum()['Purchase'].plot(kind = 'pie', autopct = '%0.1f')
# <Axes: ylabel='Purchase'>

# %%
df.groupby('City_Category').size().plot(kind = 'pie', autopct = '%0.1f')
# Out:
# <Axes: >

# %%
sns.countplot(x = df['City_Category'],hue = 'Gender', data = df)
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
df.groupby('City_Category').sum()['Purchase']
# Out:
# <ipython-input-63-363a2454a350>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('City_Category').sum()['Purchase']
# City_Category
# A    1295668797
# B    2083431612
# C    1638567969
# Name: Purchase, dtype: int64

# %%
df.groupby('City_Category').sum()['Purchase'].plot(kind = 'bar')
# Out:
# <ipython-input-64-706bfaee0f22>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('City_Category').sum()['Purchase'].plot(kind = 'bar')
# <Axes: xlabel='City_Category'>

# %%
df.groupby('City_Category').sum()['Purchase'].plot(kind = 'pie', autopct = '%0.1f')
# Out:
# <ipython-input-65-180920c89d1e>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('City_Category').sum()['Purchase'].plot(kind = 'pie', autopct = '%0.1f')
# <Axes: ylabel='Purchase'>
